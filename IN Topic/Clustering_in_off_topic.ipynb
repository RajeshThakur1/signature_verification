# %%
# !pip3 install nltk
# !pip install -U gensim
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.1)
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (4.3.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.23.5)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.10.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim) (6.3.0)

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
def preprocess_text(text):
    # Convert to lowercase
    text = text.lower()

    # Remove special characters and numbers
    text = re.sub(r'[^a-zA-Z\s]', '', text)

    # Tokenize text
    words = nltk.word_tokenize(text)

    # Remove stopwords and perform lemmatization
    lemmatizer = WordNetLemmatizer()
    stop_words = set(stopwords.words('english'))
    filtered_words = [lemmatizer.lemmatize(word) for word in words if word not in stop_words]

    return ' '.join(filtered_words)

# Read queries from a text file
with open('HR_Transport_queries.txt', 'r') as file:
    queries = file.readlines()

preprocessed_queries = [preprocess_text(query) for query in queries]
print(preprocessed_queries)
# Out:
# ['policy aim assist synechron india employee commuting', 'policy apply term employee individual', 'various mode transportation covered policy', 'could provide detail bus transport timing different shift', 'exception availability bus transport certain location', 'cab transport service work billable project', 'circumstance employee production support avail cab facility', 'considered odd shift employee avail cab service shift', 'employee request cab service based project requirement', 'elaborate process making special request cab service case medical emergency', 'situation employee use cab service official duty purpose', 'find detailed information bus route registration process', 'document provides comprehensive information cab operation find', 'policy ensure safety comfort employee commute', 'provision place ensure compliance defined policy regarding transport service', 'purpose synechron escort accompany female employee airport pickup drop', 'time escort required accompany female employee requirement effect', 'confirmation process work female employee work beyond pm', 'action taken female employee fails report arrival home synechron hotline multiple time month', 'role transport help desk ensuring female employee safety travel', 'female employee support group u recruitment expected follow safety process', 'circumstance female employee allowed disembark vehicle travel', 'purpose escort male employee vehicle female employee need picked first dropped last', 'measure taken escort available female employee travel', 'reporting manager informed female employee unable escort travel due availability issue', 'expectation regarding offering seat bus differentlyabled individual expectant mother', 'action employee take driver exceeds speed limit kmhour journey', 'employee handle instance misbehavior driver journey', 'recommended course action employee need stop journey', 'employee ensure unauthorized individual board companyprovided vehicle', 'precaution suggested employee traveling night', 'employee case emergency journey', 'company policy regarding smoking travel period', 'employee expected treat fellow colleague staff member journey', 'stance transport team regarding financial transaction employee driver personal level', 'guidance employee regarding traveling alone vehicle mindful surroundings', 'step employee take encounter emergency situation road mishap journey', 'action employee take suspect driver escort fellow cab mate journey', 'employee handle situation driver claim vehicle breakdown', 'employee ascertain genuineness driver claim vehicle breakdown inform', 'scope transportation provided transport team interview candidate employee relocation', 'outstation intercity candidate traveling pune due relocation eligible transport arrangement', 'nonsynechron employee coming interview receive transport arrangement company transport team', 'circumstance transport team arrange transport female candidate hour', 'exception special request transport handled candidate approval process', 'mechanism raising special request behalf candidate tm system transportation exception', 'specific process coordinating transportation arrangement recruitment team special case', 'general criterion deciding whether transport arrangement provided candidate employee', 'limitation condition transportation provided interview candidate relocating employee', 'female candidate avail transportation arrangement daylight hour step involved making request', 'criterion used determine availability ambulance medical emergency workplace', 'ambulance made available inhouse doctor present process obtaining one', 'requirement employee submit medical certificate ambulance provided based reporting manager approval', 'employee request regular cab transportation medical ground level approval required', 'authentication needed medical certificate provided employee', 'could explain clubbing process context medical emergency transportation', 'procedure arranging ambulance service emergency ...

# %%
# from sklearn.feature_extraction.text import TfidfVectorizer

# # Create a TF-IDF vectorizer
# tfidf_vectorizer = TfidfVectorizer()
# tfidf_matrix = tfidf_vectorizer.fit_transform(preprocessed_queries)

import numpy as np
from gensim.models import Word2Vec
from sklearn.cluster import KMeans

import matplotlib.pyplot as plt

from sklearn.manifold import TSNE

from sklearn.decomposition import PCA

# Train a Word2Vec model on your preprocessed queries
sentences = [query.split() for query in preprocessed_queries]
word2vec_model = Word2Vec(sentences, vector_size=100, window=5, min_count=1, sg=0)  # You can adjust parameters

# Create embeddings for each query by averaging word embeddings
query_embeddings = np.array([np.mean([word2vec_model.wv[word] for word in sentence], axis=0) for sentence in sentences])
query_embeddings.shape
# Out:
# (376, 100)

# %%
# Perform K-Means clustering on the query embeddings
num_clusters = 2  # You can adjust this value
kmeans = KMeans(n_clusters=num_clusters, random_state=41)
clusters = kmeans.fit_predict(query_embeddings)

# Print the cluster assignments
for query, cluster in zip(queries, clusters):
    print(f"Query: {query.strip()}\nCluster: {cluster}\n")

# from sklearn.cluster import KMeans

# # Number of clusters you want to create
# num_clusters = 2  # You can adjust this value

# # Perform K-Means clustering
# kmeans = KMeans(n_clusters=num_clusters, random_state=41)
# clusters = kmeans.fit_predict(tfidf_matrix)

# # Print the cluster assignments
# for query, cluster in zip(queries, clusters):
#     print(f"Query: {query.strip()}\nCluster: {cluster}\n")

# %%
pca = PCA(n_components=5)  # Set it to the number of queries or less
pca_result = pca.fit_transform(query_embeddings)

# Perform t-SNE dimensionality reduction on PCA results
tsne = TSNE(n_components=2, perplexity=50, n_iter=500)
tsne_result = tsne.fit_transform(pca_result)

# %%
import plotly.express as px
import plotly.io as pio
import pandas as pd

# Convert cluster numbers to strings
cluster_labels = [str(cluster) for cluster in clusters]

# Create a DataFrame with the data for Plotly
data = {

    'x': tsne_result[:, 0].tolist(),

    'y': tsne_result[:, 1].tolist(),

    'cluster': cluster_labels,

    'query': queries

}
df = pd.DataFrame(data)

# Create the scatter plot using Plotly and set custom colors
fig = px.scatter(df, x='x', y='y', hover_name='query', color="cluster",labels={"1": "In-Topic", "0": "Off-Topic"})

# Show the plot
fig.update_layout(title='t-SNE Visualization of Clusters (with Word2Vec and PCA + t-SNE)',

                  xaxis_title='t-SNE_Dim1', yaxis_title='t-SNE_Dim2')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ea2d0390-b7a8-49f7-9ee8-23318f8ae9cf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ea2d0390-b7a8-49f7-9ee8-23318f8ae9cf")) {                    Plotly.newPlot(                        "ea2d0390-b7a8-49f7-9ee8-23318f8ae9cf",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecluster=1\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["1. How does the policy aim to assist Synechron India employees in commuting?\n","2. Who does the policy apply to in terms of employees and individuals?\n","3. What are the various modes of transportation covered in the policy?\n","4. Could you provide details about the bus transport timings for different shifts?\n","5. Are there any exceptions to the availability of bus transport in certain locations?\n","6. How does the cab transport service work for billable projects?\n","7. Under what circumstances can employees in production support avail the cab facility?\n","8. What is considered as the \"Odd Shift,\" and how can employees avail cab service during this shift?\n","9. How can employees request cab service based on project requirements?\n","10. Can you elaborate on the process for making special requests for cab services, such as in the case of a medical emergency?\n","11. In what situations can employees use cab services for official duty purposes?\n","12. Where can I find more detailed information about the bus routes and registration process?\n","13. Is there a document that provides comprehensive information about cab operations? Where can I find it?\n","14. How does the policy ensure the safety and comfort of employees during their commute?\n","15. What provisions are in place to ensure compliance with the defined policies regarding transport services?\n","1. What is the purpose of having a Synechron escort accompany a female employee during airport pickups and drops?\n","2. At what time is an escort required to accompany a female employee, and when is this requirement in effect?\n","3. How does the confirmation process work for female employees who work beyond 21:00 PM?\n","4. What action is taken if a female employee fails to report her arrival at home on the Synechron hotline multiple times in a month?\n","5. What is the role of the Transport help desk in ensuring female employee safety during travel?\n","6. How are female employees in the Support group (U.S. recruitment) expected to follow the safety process?\n","7. Under what circumstances is a female employee not allowed to disembark from the vehicle during travel?\n","8. What is the purpose of having an escort or a male employee in the vehicle when the female employee needs to be picked up first or dropped off last?\n","9. What measures are taken if escorts are not available for female employees during travel?\n","10. How is the Reporting Manager informed when female employees are unable to have escorts during travel due to availability issues?\n","1. What is the expectation regarding offering seats in the bus for differently-abled individuals and expectant mothers?\n","2. What action should employees take if the driver exceeds the speed limit of 60 km\u002fhour during the journey?\n","3. How should employees handle instances of misbehavior by the driver during the journey?\n","4. What is the recommended course of action if an employee needs to stop during the journey?\n","5. How should employees ensure that unauthorized individuals do not board the company-provided vehicle?\n","6. What precautions are suggested for employees while traveling at night?\n","7. What should employees do in case of an emergency during the  ...
